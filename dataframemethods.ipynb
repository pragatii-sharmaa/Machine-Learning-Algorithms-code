# %% [markdown]
# <a href="https://colab.research.google.com/github/pragatii-sharmaa/Machine-Learning-Algorithms-code/blob/main/dataframemethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
df= pd.read_csv('/content/diabetes.csv')
df['BMI'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.sort_values(by='Glucose')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 502            6        0             68             41        0  39.0
# 349            5        0             80             32        0  41.0
# 342            1        0             68             35        0  32.0
# 182            1        0             74             20       23  27.7
# ..           ...      ...            ...            ...      ...   ...
# 228            4      197             70             39      744  36.7
# 408            8      197             74              0        0  25.9
# 8              2      197             70             45      543  30.5
# 561            0      198             66             32      274  41.3
# 661            1      199             76             43        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# ...
